# %%
import bpc.collect.crnv.br81_normal_blogger_crawler_ver01 as crawler

# %%
driver = crawler.get_driver()

# %%
driver = crawler.scroll_to_end(driver)

# %%
all_blogger_info = crawler.get_blogger_info(driver)

# %%
data = crawler.make_save_df(all_blogger_info)
# Out:
# C:\project\bigpycraft\a3rcs\bpc\collect\crnv\br81_normal_blogger_crawler_ver01.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# Out:
#           blogger_id      blogger_nick
# 0           @0701025            lydiak
# 1             @0dibi               영디비
# 2          @1fineday               강혜승
# 3    @1slide1message         브랜딩인가HR인가
# 4         @3infamily               벨롱님
# 5             @4nab2            Limbbo
# 6        @4noramyeon              사노라면
# 7           @7monaco         그림책살롱 김은정
# 8    @a0108634404123            인중 이정화
# 9           @acesaak                라휘
# 10         @alalalqq           가능성 명재영
# 11         @alexkang          강재상 Alex
# 12         @allankim         Allan Kim
# 13      @alldangdang               안경숙
# 14          @allstay          올스테이 조사장
# 15      @anan-studio                아난
# 16           @and119               예지준
# 17          @anne129               앤 쑤
# 18            @ansyd               이문연
# 19      @aroundmeeee       Ronald Jung
# 20        @artbboyan                뽀얀
# 21       @artinsight            아트인사이트
# 22       @artlecture   아트렉처 ARTLECTURE
# ...
