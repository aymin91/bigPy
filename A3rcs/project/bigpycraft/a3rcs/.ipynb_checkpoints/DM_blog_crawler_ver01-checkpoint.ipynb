# %% [markdown]
# # 다음 블로그 크롤러
#
# ### 블로그 크롤러
# - BASE_URL = 'blog.daum.net/'
# - STEP
#    1. 'blog.daum.net/(daum ID)' 에 접속
#    2. frame src 정보를 가져오기('_blog/ArticleCateList.do?blogid=(blog id)' 구하기)
#    3. form values들 구해서 남은 param 채우기
#    4. 전체 게시물 숫자 및 게시물 하단 페이지 숫자에서 마지막 페이지 구하기
#       (사용처 : 마지막 페이지 개수 구해서 for문 반복 횟수 지정)
#    5. frame 해제 url을 통해 페이지 바꿔주기
#    6. 'currentPage=' 부분 바꿔주면서 url 구하기
#    7. 수집한 url에 접속하여 게시물 가져오기
#
#
#
#
# > frame 해제 url : http://blog.daum.net/_blog/ArticleCateList.do?blogid=[블로그 ID]&vblogid=&beforePage=1&maxarticleno=0&minarticleno=0&maxregdt=0&minregdt=0&currentPage=1&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=&regdt=&date=&calv=&chgkey=0&totalcnt=0

# %%
from bs4 import BeautifulSoup
import requests

import platform
import pandas as pd

import time
import datetime
import re

# %%
BLOG_TYPE = 'DM'

BASE_URL = 'http://blog.daum.net/'
ALL_LIST_PARAM = '_blog/ArticleCateList.do?blogid='
PAGE_PARAM = '&vblogid=&beforePage=1&maxarticleno={0}&minarticleno={1}&maxregdt={2}&minregdt={3}&currentPage=1&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno={4}&regdt={5}&date=&calv=&chgkey={6}&totalcnt=0'

# %% [markdown]
# #### step1. blogger_id 받아와서 blog에 접속하여 bs4 soup을 통해 frame src 정보 가져오기

# %%
blogger_id = 'p7777877'

# %%
def get_frame_src_info(blogger_id):
    '''
        iframe의 해제를 위해 frame src 정보를 가져오는 메소드
        :param   : blogger_if(str)
        :return  : frame_src_info(str)
    '''
    url = BASE_URL + blogger_id
    req = requests.get(url)
    soup= BeautifulSoup(req.text, 'html.parser')
    frame_src_info = soup.frame['src']
    
    return frame_src_info

# %%
frame_src = get_frame_src_info(blogger_id)
frame_src
# Out:
# '/_blog/BlogTypeMain.do?blogid=0IQjd&admin='

# %% [markdown]
# #### step2. frame src에서 blog_id 정보 가져오기

# %%
def get_blog_id(frame_src_info):
    '''
        frame src에서 blog id를 가져오는 메소드
        :param   : frame_src_info(str)
        :return  : blog_id(str)
    '''
    p = re.compile('[blogid=]\w+[&]')
    m = p.search(frame_src_info)
    blog_id = m.group(0)[1:-1]
    
    return blog_id

# %%
blog_id = get_blog_id(frame_src)
blog_id
# Out:
# '0IQjd'

# %% [markdown]
# #### step3.  '전체보기' 페이지로 전환하기

# %%
def switch_all_list_page(blog_id):
    '''
        게시글 목록의 전체를 볼 수 있는 '전체보기' 페이지로 넘어가는 url을
        만들어주는 메소드
        :param   : blog_id(str)
        :return  : all_list_page_url(str)
    '''
    all_list_page_url = BASE_URL+ALL_LIST_PARAM+blog_id
    
    return all_list_page_url

# %%
all_list_page_url = switch_all_list_page(blog_id)
all_list_page_url
# Out:
# 'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd'

# %% [markdown]
# #### step4. bs4 soup을 통해 필요 param 구해서 PAGE_PARAM 채우기

# %%
def get_param_info(all_list_page_url):
    '''
        page를 넘길 때 필요한 파라미터들의 값을 페이지에서 구하고 
        PAGE_PARAM에 넣어주는 메소드
        :param   : all_list_page_url(str)
        :return  : page_param(str)
    '''
    parm_req = requests.get(all_list_page_url)
    parm_soup = BeautifulSoup(parm_req.text, 'html.parser')

    parm_form = parm_soup.find_all('form')
    
    # 구하는 value 값들이 제대로 들어 있는 곳을 찾기 위함
    for par in parm_form:
        if len(str(par.find('input')).split('\n')) == 19:
            parm_values = str(par.find('input')).split('\n')

    maxarticleno = parm_values[3].split('"')[-2]
    minarticleno = parm_values[4].split('"')[-2]
    maxregdt     = parm_values[5].split('"')[-2]
    minregdt     = parm_values[6].split('"')[-2]
    articleno    = parm_values[13].split('"')[-2]
    regdt        = parm_values[14].split('"')[-2]
    chgkey       = parm_values[17].split('"')[-2]

    page_param = PAGE_PARAM.format(maxarticleno, minarticleno, maxregdt, minregdt, articleno, regdt, chgkey)

    return page_param

# %%
page_param = get_param_info(all_list_page_url)
page_param
# Out:
# '&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=1&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0'

# %% [markdown]
# #### step5. '전체보기'가 가능한 blog_url과 page_param을 더해 frame이 해제되고 page를 바꿀 수 있는 완전한 url로 변환

# %%
def make_blog_url(all_list_page_url, page_param):
    '''
        all_list_page_url과 page_param을 합쳐 완전한 blog_url로 만들어주는 메소드
        :param   : all_list_page_url(str), page_param(str)
        :return  : blog_url(str)
    '''
    blog_url = all_list_page_url+ page_param
    
    return blog_url

# %%
blog_url = make_blog_url(all_list_page_url, page_param)
blog_url
# Out:
# 'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=1&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0'

# %% [markdown]
# #### step6. 전체 게시물 숫자 및 전체 게시물 페이지 구하기

# %%
def get_total_board_info(blog_url):
    blog_req = requests.get(blog_url)
    blog_soup = BeautifulSoup(blog_req.text, 'html.parser')

    total_board_num       = get_total_board_num(blog_soup)
    total_board_page_num  = get_total_board_page_num(blog_soup)
    print('전체 게시물은 '+total_board_num+'개, 전체 게시물 페이지는 '+total_board_page_num+'개입니다.')
    
    return total_board_page_num

# %%
def get_total_board_num(blog_soup):
    total_board = blog_soup.h2.text

    p = re.compile('[(]\d+[)]')
    m = p.search(total_board)
    total_board_num = m.group()[1:-1]
    
    return total_board_num

# %%
def get_total_board_page_num(blog_soup):
    total_board_page = blog_soup.find('div',{'id':'cNumbering'}).text

    p = re.compile('[...]\d+\s')
    m = p.search(total_board_page)
    total_board_page_num = m.group()[1:-1]
    
    return total_board_page_num

# %%
total_board_page_num = get_total_board_info(blog_url)
# Out:
# 전체 게시물은 4811개, 전체 게시물 페이지는 161개입니다.

# %% [markdown]
# #### step7. 전체 게시물 페이지 url(list) 구하기

# %%
def make_regex_page_blog_url(blog_url,total_board_page_num):
    regex_page_blog_url = list()

    for i in range(1, int(total_board_page_num)+1):
        regex_page_blog_url.append(re.sub('currentPage=1', 'currentPage='+str(i), blog_url))
    return regex_page_blog_url

# %%
regex_page_blog_url = make_regex_page_blog_url(blog_url, total_board_page_num)
regex_page_blog_url
# Out:
# ['http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=1&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=2&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=3&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=4&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=5&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=6&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=7&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=8&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=9&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=10&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=11&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=12&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=13&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=14&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=15&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=16&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=17&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=18&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=19&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=20&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=21&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=22&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=23&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=24&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=25&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=26&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=27&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=28&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=29&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=30&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=31&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=32&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=33&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=34&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=35&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=36&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=37&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=38&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=39&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=40&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=41&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=42&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=43&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=44&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=45&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=46&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=47&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=48&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=49&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=50&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=51&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=52&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=53&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=54&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=55&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=56&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=57&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=58&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=59&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=60&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=61&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=62&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=63&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=64&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=65&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=66&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=67&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=68&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=69&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=70&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=71&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=72&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=73&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=74&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=75&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=76&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=77&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=78&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=79&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=80&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=81&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=82&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=83&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=84&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=85&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=86&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=87&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=88&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=89&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=90&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=91&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=92&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=93&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=94&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=95&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=96&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=97&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=98&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=99&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=100&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=101&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=102&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=103&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=104&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=105&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=106&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=107&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=108&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=109&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=110&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=111&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=112&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=113&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=114&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=115&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=116&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=117&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=118&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=119&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=120&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=121&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=122&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=123&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=124&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=125&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=126&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=127&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=128&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=129&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=130&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=131&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=132&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=133&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=134&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=135&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=136&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=137&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=138&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=139&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=140&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=141&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=142&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=143&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=144&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=145&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=146&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=147&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=148&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=149&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=150&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=151&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=152&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=153&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=154&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=155&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=156&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=157&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=158&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=159&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=160&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0',
#  'http://blog.daum.net/_blog/ArticleCateList.do?blogid=0IQjd&vblogid=&beforePage=1&maxarticleno=6984599&minarticleno=6984571&maxregdt=20191023082958&minregdt=20190819055900&currentPage=161&listScale=12&viewKind=T&dispkind=B2202&CATEGORYID=0&categoryId=0&articleno=6984599&regdt=20191023082958&date=&calv=&chgkey=Tvpw4cA86OF3W52MmyyIiRgaC7LUoyoDhdxPCx.Nfck0&totalcnt=0']

# %% [markdown]
# # 다음 블로그 parsing 모듈 종류
#
# ### 공통사항 : 아래 TAG들은 div, id='cContent' 안에 들어있음
# 1. WebAList - WebAFirst + WebEList
#     : 매 페이지의 첫번째 게시물이 WebAFirst에 있고, 나머지 게시물(두번째 게시물~)은 WebEList에 있음
# 2. WebBTable
#     : 일반적인 게시판 목록
# 3. WebCList
#     : 일반적인 게시판 목록(오른쪽에 소게시판이 있음)
# 4. WebEList
#     : 일반적인 게시판 목록
# 5. DiaryList
#     : 게시판 왼쪽에 달력 표시가 있음
# 6. GalleryList
#     : 게시판 목록에 있는 게시글들이 그림으로 되어있음
# 7. artList
#     : 일반적인 게시판 목록

# %% [markdown]
# #### step8. 한 페이지에 있는 모든 게시물 url 가져오기

# %%
def get_board_url(one_regex_page_blog_url):
    '''
        게시물 1개 페이지에 있는 게시물 url을 수집하는 메소드
        :param   : one of regex_page_blog_url(str/one value of list)
        :return  : board_url(list)        
    '''
    # 게시물 1 페이지 파싱
    board_req = requests.get(one_regex_page_blog_url)
    board_soup = BeautifulSoup(board_req.text, 'html.parser')

    board_content = board_soup.find('div', {'id':'cContent'})

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_alist = True if board_content.find('table',{'class':'WebAList'}) else False

    if is_valid_alist:
        board_url_list = type_webalist(board_content)
        print("This blog's type is WebAList.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_btable = True if board_soup.find('div',{'class':'WebBTable'}) else False

    if is_valid_btable:
        board_url_list = type_webbtable(board_content)
        print("This blog's type is WebBTable.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_clist = True if board_soup.find('table',{'class':'WebCList'}) else False

    if is_valid_clist:
        board_url_list = type_webclist(board_content)
        print("This blog's type is WebCList.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_elist = True if board_soup.find('div',{'class':'webERightP'}) else False

    if is_valid_elist:
        board_url_list = type_webelist(board_content)
        print("This blog's type is webERightP.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_diary = True if board_soup.find('table',{'class':'DiaryTList'}) else False

    if is_valid_diary:
        board_url_list = type_diarylist(board_content)
        print("This blog's type is DiaryTList.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_gallery = True if board_soup.find('ul',{'class':'GalleryList'}) else False

    if is_valid_gallery:
        board_url_list = type_gallerylist(board_content)
        print("This blog's type is GalleryList.")
    else: pass

    # 파싱 후, div, id='cContent'에 어떤 'List' 형식인지 판별하기
    is_valid_arti = True if board_soup.find('table',{'class':'artiList'}) else False

    if is_valid_arti:
        board_url_list = type_artlist(board_content)
        print("This blog's type is artiList.")
    else: pass

    return board_url_list

# %% [markdown]
# #### 1. WebAList parsing

# %%
def type_webalist(board_content):
    '''
        board_content의 type이 WebAList인 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # WebAList = WebAFirst + WebAList
    board_url = list()

    # WebAFirst
    board_first = board_content.find('div',{'class':'webAFirst'})
    board_url.append(BASE_URL+board_first.a['href'][1:])

    # WebAList
    board = board_content.find_all('td',{'class':'title'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 2. WebBTable parsing

# %%
def type_webbtable(board_content):
    '''
        board_content의 type이 WebBTable 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # WebBTable
    board_url = list()
    
    board = board_content.find_all('td',{'class':'title'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 3. WebCList parsing

# %%
def type_webclist(board_content):
    '''
        board_content의 type이 WebCList 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # WebCList
    board_url = list()
    
    board = board_content.find_all('td',{'class':'title'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 4. WebEList parsing

# %%
def type_webelist(board_content):
    '''
        board_content의 type이 WebEList 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # WebEList
    board_url = list()

    board = board_content.find_all('td',{'class':'title'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 5. DiaryList parsing

# %%
def type_diarylist(board_content):
    '''
        board_content의 type이 DiaryList 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # DiaryList
    board_url = list()
    
    board = board_content.find_all('td',{'class':'contArea'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 6. GalleryList parsing

# %%
def type_gallerylist(board_content):
    '''
        board_content의 type이 GalleryList 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # GalleryList
    board_url = list()

    board_gallery = board_content.find('ul',{'class':'GalleryList'})
    board = board_gallery.find_all('li')
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %% [markdown]
# #### 7. artList parsing

# %%
def type_artlist(board_content):
    '''
        board_content의 type이 artList 경우에 type에 맞게 tag를 파싱해 url을 가져오는 메소드
        :param   : board_content(bs4.tag)
        :return  : board_url(list)
    '''
    # artList
    board_url = list()

    board = board_content.find_all('td',{'class':'title'})
    for t in board:
        board_url.append(BASE_URL+t.a['href'][1:])
    
    return board_url

# %%
board_url_list = list()
for i in range(0, len(regex_page_blog_url)):
    print(i)
    board_url_list += get_board_url(regex_page_blog_url[i])
# Out:
# 0
# This blog's type is WebAList.
# 1
# This blog's type is WebAList.
# 2
# This blog's type is WebAList.
# 3
# This blog's type is WebAList.
# 4
# This blog's type is WebAList.
# 5
# This blog's type is WebAList.
# 6
# This blog's type is WebAList.
# 7
# This blog's type is WebAList.
# 8
# This blog's type is WebAList.
# 9
# This blog's type is WebAList.
# 10
# This blog's type is WebAList.
# 11
# This blog's type is WebAList.
# 12
# This blog's type is WebAList.
# 13
# This blog's type is WebAList.
# 14
# This blog's type is WebAList.
# 15
# This blog's type is WebAList.
# 16
# This blog's type is WebAList.
# 17
# This blog's type is WebAList.
# 18
# This blog's type is WebAList.
# 19
# This blog's type is WebAList.
# 20
# This blog's type is WebAList.
# 21
# This blog's type is WebAList.
# 22
# This blog's type is WebAList.
# 23
# This blog's type is WebAList.
# 24
# This blog's type is WebAList.
# 25
# This blog's type is WebAList.
# 26
# This blog's type is WebAList.
# 27
# This blog's type is WebAList.
# 28
# This blog's type is WebAList.
# 29
# This blog's type is WebAList.
# 30
# This blog's type is WebAList.
# 31
# This blog's type is WebAList.
# 32
# This blog's type is WebAList.
# 33
# This blog's type is WebAList.
# 34
# This blog's type is WebAList.
# 35
# This blog's type is WebAList.
# 36
# This blog's type is WebAList.
# 37
# This blog's type is WebAList.
# 38
# This blog's type is WebAList.
# 39
# This blog's type is WebAList.
# 40
# This blog's type is WebAList.
# 41
# This blog's type is WebAList.
# 42
# This blog's type is WebAList.
# 43
# This blog's type is WebAList.
# 44
# This blog's type is WebAList.
# 45
# This blog's type is WebAList.
# 46
# This blog's type is WebAList.
# 47
# This blog's type is WebAList.
# 48
# This blog's type is WebAList.
# 49
# This blog's type is WebAList.
# 50
# This blog's type is WebAList.
# 51
# This blog's type is WebAList.
# 52
# This blog's type is WebAList.
# 53
# This blog's type is WebAList.
# 54
# This blog's type is WebAList.
# 55
# This blog's type is WebAList.
# 56
# This blog's type is WebAList.
# 57
# This blog's type is WebAList.
# 58
# This blog's type is WebAList.
# 59
# This blog's type is WebAList.
# 60
# This blog's type is WebAList.
# 61
# This blog's type is WebAList.
# 62
# This blog's type is WebAList.
# 63
# This blog's type is WebAList.
# 64
# This blog's type is WebAList.
# 65
# This blog's type is WebAList.
# 66
# This blog's type is WebAList.
# 67
# This blog's type is WebAList.
# 68
# This blog's type is WebAList.
# 69
# This blog's type is WebAList.
# 70
# This blog's type is WebAList.
# 71
# This blog's type is WebAList.
# 72
# This blog's type is WebAList.
# 73
# This blog's type is WebAList.
# 74
# This blog's type is WebAList.
# 75
# This blog's type is WebAList.
# 76
# This blog's type is WebAList.
# 77
# This blog's type is WebAList.
# 78
# This blog's type is WebAList.
# 79
# This blog's type is WebAList.
# 80
# This blog's type is WebAList.
# 81
# This blog's type is WebAList.
# 82
# This blog's type is WebAList.
# 83
# This blog's type is WebAList.
# 84
# This blog's type is WebAList.
# 85
# This blog's type is WebAList.
# 86
# This blog's type is WebAList.
# 87
# This blog's type is WebAList.
# 88
# This blog's type is WebAList.
# 89
# This blog's type is WebAList.
# 90
# This blog's type is WebAList.
# 91
# This blog's type is WebAList.
# 92
# This blog's type is WebAList.
# 93
# This blog's type is WebAList.
# 94
# This blog's type is WebAList.
# 95
# This blog's type is WebAList.
# 96
# This blog's type is WebAList.
# 97
# This blog's type is WebAList.
# 98
# This blog's type is WebAList.
# 99
# This blog's type is WebAList.
# 100
# This blog's type is WebAList.
# 101
# This blog's type is WebAList.
# 102
# This blog's type is WebAList.
# 103
# This blog's type is WebAList.
# 104
# This blog's type is WebAList.
# 105
# This blog's type is WebAList.
# 106
# This blog's type is WebAList.
# 107
# This blog's type is WebAList.
# 108
# This blog's type is WebAList.
# 109
# This blog's type is WebAList.
# 110
# This blog's type is WebAList.
# 111
# This blog's type is WebAList.
# 112
# This blog's type is WebAList.
# 113
# This blog's type is WebAList.
# 114
# This blog's type is WebAList.
# 115
# This blog's type is WebAList.
# 116
# This blog's type is WebAList.
# 117
# This blog's type is WebAList.
# 118
# This blog's type is WebAList.
# 119
# This blog's type is WebAList.
# 120
# This blog's type is WebAList.
# 121
# This blog's type is WebAList.
# 122
# This blog's type is WebAList.
# 123
# This blog's type is WebAList.
# 124
# This blog's type is WebAList.
# 125
# This blog's type is WebAList.
# 126
# This blog's type is WebAList.
# 127
# This blog's type is WebAList.
# 128
# This blog's type is WebAList.
# 129
# This blog's type is WebAList.
# 130
# This blog's type is WebAList.
# 131
# This blog's type is WebAList.
# 132
# This blog's type is WebAList.
# 133
# This blog's type is WebAList.
# 134
# This blog's type is WebAList.
# 135
# This blog's type is WebAList.
# 136
# This blog's type is WebAList.
# 137
# This blog's type is WebAList.
# 138
# This blog's type is WebAList.
# 139
# This blog's type is WebAList.
# 140
# This blog's type is WebAList.
# 141
# This blog's type is WebAList.
# 142
# This blog's type is WebAList.
# 143
# This blog's type is WebAList.
# 144
# This blog's type is WebAList.
# 145
# This blog's type is WebAList.
# 146
# This blog's type is WebAList.
# 147
# This blog's type is WebAList.
# 148
# This blog's type is WebAList.
# 149
# This blog's type is WebAList.
# 150
# This blog's type is WebAList.
# 151
# This blog's type is WebAList.
# 152
# This blog's type is WebAList.
# 153
# This blog's type is WebAList.
# 154
# This blog's type is WebAList.
# 155
# This blog's type is WebAList.
# 156
# This blog's type is WebAList.
# 157
# This blog's type is WebAList.
# 158
# This blog's type is WebAList.
# 159
# This blog's type is WebAList.
# 160
# This blog's type is WebAList.

# %%
len(board_url_list) #4811
# Out:
# 4812

# %% [markdown]
# #### step9. blog_type, blogger_id, 수집한 게시물 url, post_num을 dataframe에 저장

# %%
def make_basic_DF():
    '''
        기본 데이터프레임을 만들어 주는 모듈
        :return: df
    '''
    dataframe = pd.DataFrame()
    dataframe['blog_type']       = ''
    dataframe['blogger_id']      = ''
    dataframe['post_num']        = ''
    dataframe['key']             = ''
    dataframe['board_url']       = ''
    dataframe['title']           = ''
    dataframe['content']         = ''
    dataframe['board_category']  = ''
    dataframe['blogger_nick']    = ''
    dataframe['date']            = ''

    return dataframe

def insert_DM_DF(dataframe, blogger_id, board_url_list):
    blog_type = BLOG_TYPE
    blogger_id = blogger_id

    dataframe['board_url']   = board_url_list
    dataframe['blog_type']   = blog_type
    dataframe['blogger_id']  = blogger_id

    pattern = re.compile('articleno=\w+')
    for u in range(0, len(board_url_list)):
        reg_post_num              = pattern.search(board_url_list[u])
        post_num                  = reg_post_num.group().split('=')[1]
        dataframe['post_num'][u]  = post_num

    for i in range(0, len(dataframe)):
        dataframe['key'][i] = blog_type+"_"+blogger_id+"_"+dataframe['post_num'][i]

    return dataframe

# %%
dm_df = make_basic_DF()
dm_df = insert_DM_DF(dm_df, blogger_id, board_url_list)

# %%
dm_df
# Out:
#      blog_type blogger_id post_num                  key  \
# 0           DM   p7777877  6984599  DM_p7777877_6984599
# 1           DM   p7777877  6984598  DM_p7777877_6984598
# 2           DM   p7777877  6984597  DM_p7777877_6984597
# 3           DM   p7777877  6984596  DM_p7777877_6984596
# 4           DM   p7777877  6984595  DM_p7777877_6984595
# 5           DM   p7777877  6984594  DM_p7777877_6984594
# 6           DM   p7777877  6984593  DM_p7777877_6984593
# 7           DM   p7777877  6984592  DM_p7777877_6984592
://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 11    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 12    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 13    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 14    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 15    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 16    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 17    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 18    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 19    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 20    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 21    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 22    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 23    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 24    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 25    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 26    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 27    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 28    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 29    http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# ...                                                 ...   ...     ...
# 4782  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4783  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4784  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4785  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4786  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4787  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4788  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4789  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4790  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4791  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4792  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4793  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4794  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4795  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4796  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4797  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4798  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4799  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4800  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4801  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4802  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4803  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4804  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4805  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4806  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4807  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4808  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4809  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4810  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
# 4811  http://blog.daum.net/_blog/BlogTypeView.do?blo...   NaN     NaN
#
#      board_category blogger_nick date
# 0               NaN          NaN  NaN
# 1               NaN          NaN  NaN
# 2               NaN          NaN  NaN
# 3               NaN          NaN  NaN
# 4               NaN          NaN  NaN
# 5               NaN          NaN  NaN
# 6               NaN          NaN  NaN
# 7               NaN          NaN  NaN
# 8               NaN          NaN  NaN
# 9               NaN          NaN  NaN
# 10              NaN          NaN  NaN
# 11              NaN          NaN  NaN
# 12              NaN          NaN  NaN
# 13              NaN          NaN  NaN
# 14              NaN          NaN  NaN
# 15              NaN          NaN  NaN
# 16              NaN          NaN  NaN
# 17              NaN          NaN  NaN
# 18              NaN          NaN  NaN
# 19              NaN          NaN  NaN
# 20              NaN          NaN  NaN
# 21              NaN          NaN  NaN
# 22              NaN          NaN  NaN
# 23              NaN          NaN  NaN
# 24              NaN          NaN  NaN
# 25              NaN          NaN  NaN
# 26              NaN          NaN  NaN
# 27              NaN          NaN  NaN
# 28              NaN          NaN  NaN
# 29              NaN          NaN  NaN
# ...             ...          ...  ...
# 4782            NaN          NaN  NaN
# 4783            NaN          NaN  NaN
# 4784            NaN          NaN  NaN
# 4785            NaN          NaN  NaN
# 4786            NaN          NaN  NaN
# 4787            NaN          NaN  NaN
# 4788            NaN          NaN  NaN
# 4789            NaN          NaN  NaN
# 4790            NaN          NaN  NaN
# 4791            NaN          NaN  NaN
# 4792            NaN          NaN  NaN
# 4793            NaN          NaN  NaN
# 4794            NaN          NaN  NaN
# 4795            NaN          NaN  NaN
# 4796            NaN          NaN  NaN
# 4797            NaN          NaN  NaN
# 4798            NaN          NaN  NaN
# 4799            NaN          NaN  NaN
# 4800            NaN          NaN  NaN
# 4801            NaN          NaN  NaN
# 4802            NaN          NaN  NaN
# 4803            NaN          NaN  NaN
# 4804            NaN          NaN  NaN
# 4805            NaN          NaN  NaN
# 4806            NaN          NaN  NaN
# 4807            NaN          NaN  NaN
# 4808            NaN          NaN  NaN
# 4809            NaN          NaN  NaN
# 4810            NaN          NaN  NaN
# 4811            NaN          NaN  NaN
#
# [4812 rows x 10 columns]

# %%
print(dm_df['board_url'][0])
print(dm_df['post_num'][0])
# Out:
# http://blog.daum.net/_blog/BlogTypeView.do?blogid=0uYPK&articleno=925&categoryId=0®dt=20191022040000
# 925

# %%
board_url_list[0]
# Out:
# 'http://blog.daum.net/_blog/BlogTypeView.do?blogid=0uYPK&articleno=925&categoryId=0®dt=20191022040000'

# %% [markdown]
# #### step10. 게시글 parsing

# %%
from selenium import webdriver

PROJECT_ROOT = '/project/bigpycraft/a3rcs/'
WD_CHROME_PATH_WIN   = 'driver/chromedriver.exe'
WD_CHROME_PATH_MAC   = 'driver/macos/chromedriver'
WD_CHROME_PATH_LINUX = 'driver/linux/chromedriver'

def get_driver() :
    '''
        웹드라이브를 호출하는 메소드
        parmam : None
        Result : driver  , ChromeWebDriver
    '''

    if platform.system() == 'Windows' :  # MacOS
        driver = webdriver.Chrome(executable_path=PROJECT_ROOT + WD_CHROME_PATH_WIN)
    elif platform.system() == 'Darwin' :  # Windows
        driver = webdriver.Chrome(executable_path=PROJECT_ROOT + WD_CHROME_PATH_MAC)
    elif platform.system() == 'Linux' :  # Linux
        driver = webdriver.Chrome(executable_path=PROJECT_ROOT + WD_CHROME_PATH_LINUX)
    else :
        print("It's unknown system. Hangul fonts are not supported!")

    return driver

# %%
def regex_front_content_text(content_text):
    p1_start = re.compile('[<!--]')
    m1_start = p1_start.search(content_text)

    p1_end = re.compile('[>]')
    m1_end = p1_end.search(content_text)

    regex_content_text = re.sub(content_text[m1_start.start():m1_end.end()],'',content_text)
    
    return regex_content_text

# %%
def regex_tail_content_text(content_text):
    
    regex_content_text = content_text[:content_text.find('var flashVersion')]
    
    return regex_content_text

# %%
def get_head_info(df_board_url):
    
    head_info = dict()
    
    brd_req = requests.get(df_board_url)
    brd_soup = BeautifulSoup(brd_req.text, 'html.parser')

    title           = brd_soup.find('strong',{'class':'cB_Title cB_TitleImage'}).text.replace('\n','').replace('\t','').rstrip()
    board_category  = brd_soup.find('span',{'class':'cB_Folder'}).text
    nickname        = brd_soup.find('span',{'class':'cB_Name'}).text
    upload_date     = brd_soup.find('span',{'class':'cB_Tdate'}).text
    
    head_info['title']           = title
    head_info['board_category']  = board_category
    head_info['nickname']        = nickname
    head_info['date']            = upload_date[:10].replace('.', '')
    
    return head_info

# %%
def get_content_info(driver, df_board_url, df_post_num):
    
    content_info = dict()
    
    
    driver.get(df_board_url)
    driver.switch_to_frame('if_b_'+df_post_num)
    test_soup = BeautifulSoup(driver.page_source, 'html.parser')

    content = re.sub('\n|\u200b|\xa0|\uf0fc|\t', '', test_soup.find('div',{'id':'cContent'}).text)

    content = regex_tail_content_text(regex_front_content_text(content))
    
    content_info['content'] = content

    return content_info

# %%
def gather_all_content(dm_df):
    
    all_content_info = list()
    
    driver = get_driver()
    for i in range(0, 5):
        
        print(i,'번째 줄입니다.', dm_df['board_url'][i])
        head_info = get_head_info(dm_df['board_url'][i])
        content_info = get_content_info(driver, dm_df['board_url'][i], dm_df['post_num'][i])
        
        head_info.update(content_info)
        
        all_content_info.append(head_info)
    
    return all_content_info

# %%
dd = gather_all_content(dm_df)
# Out:
# 0 번째 줄입니다. http://blog.daum.net/_blog/BlogTypeView.do?blogid=0IQjd&articleno=6984599&categoryId=0®dt=20191023082958
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: DeprecationWar
질 못했고승용차를 비롯해서 주차시설 양호합니다프런트저녁을 거나하게 반주와 함께 먹은 지라2차고 뭐고 빨리 꿈나라 여행 하고 싶네요침대 쿠션 좋고침구 청결 하구옆의 룸과 소음 철저히 차단되었고구석구석 노트북에서부터 카메라와스마트폰 등 충전할 코드 많으며무선인터넷이나 와이 파이거팡팡 잘 터지네요무료 생수 1일 2병 무료 차(TEA) 커피포트도 있네요비데, 목욕가운, 욕조, 헤어드라이기,샤워캡, 스펀지, 1회용 치약과 칫솔, 욕실용품 등이 완벽하게 갖추어졌다 유성온천에서 몸을 푹 담그고 온천욕도좋겠으나 이러한 욕조에 미지근한물을 가득하게 담아서 몸을 푹 담근 후 목욕하는 방법도좋을 듯하지만 이런저런 일과예전에는 그리하였으나 현재는샤워만 하니 사용하지 않게 됩니다롯데시티 호텔 대전에서 내려다본유성시 갑천 주변의 아름다운 야경덩치는 큰 윤중이 강력한 다이어트 중인데요평소에 공깃밥 기준으로 하루 한 공기 반정도를 먹는 식사 양을 이렇게 줄여서가져온 모습입니다밥이나 토스트는 한 톨이나 한조각도 없이삶은 달걀과 부드러운 식감이 일품인스크램블드 에그와 생연어, 베이컨, 단호박, 낫또, 즉석 달걀프라이와 스크램블,빵 종류, 케이크, 수많은 종류의 맛나는 요리들이 있으나 더 이상은 쳐다보지않기로 하고 패스김치국인가 해장국 같은 수프가 또 2가지 정도 있었는데요 윤중은 양송이 수프를 더 좋아한다함께 식사를 한 일행들이 물김치가너무너무 시원하고 간도 잘 맞으면서맛난다며 이렇게 담아서 주신다단숨에 한 그릇을 원샷하듯 마셔버렸다이럴 때 최고의 맛이라 한다이런 물김치에 삶은 국수를 넣고 먹으면 환상적인 맛이 될듯싶다떠다 준사람이 누굴까요?난 알지롱 ㅎ배는 부르지만 연어 한 조각을 또 먹고후식으로 가져와서 먹은 과일과 요플레, 사과주스 그리고 커피입니다가지고 오지는 않았으나오렌지주스, 토마토 주스, 우유등 여러 가지의 음료를 비롯한 먹을거리가 많았지만 사과주스만 제외하고 패스오늘 맛나는 요리를 눈앞에 두고선다이어트때문에 먹지 않으려고 참느라고 힘들었다롯데시티호텔 대전대전광역시 유성구 엑스포로 123번길 33(도룡동 4-30)042-333-1000    '}]

# %%
def update_save_DM_DF(dm_df, all_content_info, blogger_id) :
    '''
    기존에 만들어져 있던 데이터 프레임에 모든 게시물의 내용을 추가 및 저장

    :params : dataframe, parsed content, blog_type, user_id
    :return : dataframe(all_information in it)

    '''

    blog_type = BLOG_TYPE

    for num in range(len(all_content_info)) :
        dm_df['title'][num]           = all_content_info[num]['title']
        dm_df['content'][num]         = all_content_info[num]['content']
        dm_df['board_category'][num]  = all_content_info[num]['board_category']
        dm_df['blogger_nick'][num]    = all_content_info[num]['nickname']
        dm_df['date'][num]            = all_content_info[num]['date']

#     dataframe.to_csv('{0}_{1}.csv'.format(blog_type, blogger_id), index = False)

    return dm_df

# %%
dm_df = update_save_DM_DF(dm_df, info, blogger_id)
