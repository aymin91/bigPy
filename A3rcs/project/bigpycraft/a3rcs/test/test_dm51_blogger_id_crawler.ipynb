# %%
import bpc.collect.crnv.dm51_blogger_id_crawler_ver01 as crawler

# %%
driver = crawler.get_driver()

# %%
all_now_blogger_info = crawler.gather_now_blogger_info(driver)

# %%
crawler.click_more_btn(driver)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="0940d3b882b61377ebbee1ba479d59b4")>

# %%
'''
crawler.click_more_btn(driver) ISSUE
1. '더보기' 버튼을 누르다가 그 위치에 위치하는 블로그를 눌러서 블로그 창이 열림
2. '더보기' 버튼이 마저 다 열리지 않았는데 끝남
'''

# %%
all_friend_empathize_blogger_info = crawler.gather_friend_empathize_blogger_info(driver)

# %%
df = crawler.make_save_df(all_now_blogger_info, all_friend_empathize_blogger_info)

# %%
df
# Out:
#         blogger_id   blogger_nick
# 0      01195077236        행복한 요리사
# 1        5949hkkim          hkkim
# 2        a-messiah          엣지플러스
# 3        amigohula      아미고 Amigo
# 4           anesbs            아네스
# 5        arong0429            솜사탕
# 6         aura0621          압박의달인
# 7        barim1007            김슬다
# 8          bhs5038            방도리
# 9         bmkmotor         노당 큰형부
# 10        bolee591         진흙속의연꽃
# 11         bori-yo             토함
# 12          c41051     씨밀레 ( 김건수
# 13    chounsoon788           흰날꽃별
# 14      chungshim7             청심
# 15         cloud07          CLOUD
# 16      clouddrift       하이얀 뭉게구름
# 17          cnn082           타임리스
# 18        cognos57         손장혁 요한
# 19       dhtpduf68            몽실이
# 20        dlhy1253         산인(山人)
# 21   dlwhdgkrmarkd           금강조아
# 22          doche2           도깨비꽃
# 23       dywjd9090           아젤리아
# 24       elara1020            엘아라
# 25           endks             두안
# ...
